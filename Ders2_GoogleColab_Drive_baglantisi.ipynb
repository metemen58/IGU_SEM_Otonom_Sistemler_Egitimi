# %% [markdown]
# İGÜ SEM OTONOM SİSTEMLER EĞİTİMİ
#
# Bu kod bloğu üzerinde google drive ile google colab platformlarının eşleşmesi sağlanmaktadır. Eşleşme anında drive alanınızda aşağıdaki kod içerisinde olan "IGUSEM_OTONOM" dosyası olmak zorundadır.
#
# Ocak 2026

# %%
print("Merhaba Hayat, IGU SEM EĞİTİMİ OTONOM SİSTEMLER 20.01.2026")
# Out:
# Merhaba Hayat, IGU SEM EĞİTİMİ OTONOM SİSTEMLER 20.01.2026

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM
